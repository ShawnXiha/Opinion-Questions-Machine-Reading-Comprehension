# %%
import pandas as pd
import numpy as np
import seaborn
import os
import jieba

# %%
# !ls ../inputs/
# Out:
# ai_challenger_oqmrc_testa.json	      ai_challenger_oqmrc_validationset.json
# ai_challenger_oqmrc_trainingset.json

# %%
train_raw_df = pd.read_json("../inputs/ai_challenger_oqmrc_trainingset.json", orient="record", lines=True)

# %%
test_raw_df = pd.read_json("../inputs/ai_challenger_oqmrc_testa.json", orient="record", lines=True)

# %%
val_raw_df = pd.read_json("../inputs/ai_challenger_oqmrc_validationset.json", orient="record", lines=True)

# %%
# Out:
#        alternatives answer                                            passage  \
# 0         有|没有|无法确定      有  动漫好看的H：爱的魔法，KEY的作品，喧嚣学院，草莓100%，双恋，爱丽丝学园，灼眼的夏娜，...
# 1         能|不能|无法确定      能  醋泡鸡蛋确实具有一定美白嫩化肌肤、提高皮肤亮度、祛斑的效果，因为白醋中含有的醋酸可以加速表皮...
# 2      听不懂|听得懂|无法确定    听不懂                              人有人言，兽有兽语。动物是不会听懂人说话的
# 3         无法确定|大|不大   无法确定  1.前期投资约5-10万元设备投资：柜台、门面装修、电脑及简单家具，一次性投入约2万元。2....
# 4         会|不会|无法确定      会                    性接触没有保护措施，是有感染的几率的，艾滋病没有特异性的症状。
# 5         不能|能|无法确定     不能  最起码再来月经后在考虑上环，一般在月经干净后3天左右去上环，这时候是最佳的时间。现在还没有来...
# 6         有|没有|无法确定      有  惠州南站 惠州南站，位于惠州市惠阳区，是厦深铁路沿线大站之一。隶属广州铁路（集团）公司管辖，...
# 7         有|没有|无法确定      有                     陈立农有弟弟吗 一个妹妹一个弟弟 当然是亲生的 妹妹比弟弟大
# 8          是|否|无法确定      是  飞机在起飞和降落时是最危险的。飞中远距离的飞机所携带的燃油比较多，如果不放掉大部分燃油，着陆...
# 9         不行|行|无法确定     不行  建议入院行X片检查，必要时行踝关节CT检查排除骨折。如无骨折，则考虑韧带损伤，建议受伤关节制...
# 10        不能|能|无法确定     不能       对经期有影响发生月经不调的情况,建议在月经期间多喝红糖水，避免着凉，不吃辛辣刺激的食物。
# ...
